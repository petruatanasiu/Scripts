# %% [markdown]
# # Introduction to Python

# %%
x = 1
y = "Devops"
animals = ["python","dog","cat"]

# %%
animals.sort()

# %%
animals
# Out:
# ['cat', 'dog', 'python']

# %%
dir(animals)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
# dict { key: value }

danimals = {"reptile":"python", "primate":"monkey","mammal":"dog"}

# %%
dir(danimals)
# Out:
# ['__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__ror__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']

# %%
danimals.keys()
# Out:
# dict_keys(['reptile', 'primate', 'mammal'])

# %%
danimals.values()
# Out:
# dict_values(['python', 'monkey', 'dog'])

# %%
danimals["reptile"] = "PYTHON"

# %%
danimals
# Out:
# {'reptile': 'PYTHON', 'primate': 'monkey', 'mammal': 'dog'}

# %%
for animal in danimals.values():
    print(animal.upper())
# Out:
# PYTHON
# MONKEY
# DOG

# %%
danimals.update({"fish":"shark"})

# %%
danimals
# Out:
# {'reptile': 'PYTHON', 'primate': 'monkey', 'mammal': 'dog', 'fish': 'shark'}

# %%
danimals.get("fish")
# Out:
# 'shark'

# %%
danimals['fish']
# Out:
# 'shark'

# %%
import requests

# %%
r = requests.get("https://petstore.swagger.io/v2/pet/1")

# %%
r.text
# Out:
# '{"id":1,"category":{"id":1,"name":"cat"},"name":"dog","photoUrls":[],"tags":[],"status":"sold"}'

# %%
r.raw

# %%
r.request
# Out:
# <PreparedRequest [GET]>

# %%
r.status_code
# Out:
# 200

# %%
import math
result = math.sqrt(9)
result
# Out:
# 3.0

# %%
from math import sqrt
result = sqrt(9)
result
# Out:
# 3.0

# %%
import requests
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup()

# %%
soup

# %%
r = requests.get("https://en.wikipedia.org/wiki/Python_(genus)")

# %%
html_doc = r.text

# %%
soup = BeautifulSoup(html_doc, 'html.parser')

# %%
soup.p
# Out:
# <p class="mw-empty-elt">
# </p>

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-enabled vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-zebra-design-disabled" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Python (genus) - Wikipedia
#   </title>
#   <script>
# ...

# %%
soup.find_all('a')
# Out:
# [<a class="mw-jump-link" href="#bodyContent">Jump to content</a>,
#  <a accesskey="z" href="/wiki/Main_Page" title="Visit the main page [z]"><span>Main page</span></a>,
#  <a href="/wiki/Wikipedia:Contents" title="Guides to browsing Wikipedia"><span>Contents</span></a>,
#  <a href="/wiki/Portal:Current_events" title="Articles related to current events"><span>Current events</span></a>,
#  <a accesskey="x" href="/wiki/Special:Random" title="Visit a randomly selected article [x]"><span>Random article</span></a>,
#  <a href="/wiki/Wikipedia:About" title="Learn about Wikipedia and how it works"><span>About Wikipedia</span></a>,
#  <a href="//en.wikipedia.org/wiki/Wikipedia:Contact_us" title="How to contact Wikipedia"><span>Contact us</span></a>,
# ...

# %%
soup.find(id="reference")

# %%
for link in soup.find_all('a'):
    print(link.get('href'))
# Out:
# #bodyContent
# /wiki/Main_Page
# /wiki/Wikipedia:Contents
# /wiki/Portal:Current_events
# /wiki/Special:Random
# /wiki/Wikipedia:About
# //en.wikipedia.org/wiki/Wikipedia:Contact_us
# https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&utm_medium=sidebar&utm_campaign=C13_en.wikipedia.org&uselang=en
# /wiki/Help:Contents
# /wiki/Help:Introduction
# /wiki/Wikipedia:Community_portal
# /wiki/Special:RecentChanges
# /wiki/Wikipedia:File_upload_wizard
# /wiki/Main_Page
# /wiki/Special:Search
# /w/index.php?title=Special:CreateAccount&returnto=Python+%28genus%29
# /w/index.php?title=Special:UserLogin&returnto=Python+%28genus%29
# /w/index.php?title=Special:CreateAccount&returnto=Python+%28genus%29
# /w/index.php?title=Special:UserLogin&returnto=Python+%28genus%29
# /wiki/Help:Introduction
# /wiki/Special:MyContributions
# /wiki/Special:MyTalk
# #
# #Taxonomy
# #Distribution_and_habitat
# #Invasive
# #Uses
# #As_pets
# #Etymology
# #References
# #External_links
# ...

# %%
print(soup.get_text())
# Out:
# Python (genus) - Wikipedia
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Jump to content
#
#
#
#
#
#
#
# Main menu
#
#
#
#
#
# Main menu
# move to sidebar
# hide
#
#
#
# 		Navigation
#
#
#
# Main pageContentsCurrent eventsRandom articleAbout WikipediaContact usDonate
#
#
#
#
#
# 		Contribute
#
#
#
# HelpLearn to editCommunity portalRecent changesUpload file
#
#
#
#
#
# Languages
#
# Language links are at the top of the page across from the title.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Search
#
#
#
#
#
#
#
#
#
#
#
# Search
#
#
#
#
#
#
#
#
# Create accountLog in
#
#
#
#
#
#
# Personal tools
#
#
#
#
#
#  Create account Log in
#
#
#
#
#
# 		Pages for logged out editors learn more
#
#
#
# ContributionsTalk
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Contents
# move to sidebar
# hide
#
#
#
#
# (Top)
#
#
#
#
#
# 1Taxonomy
#
#
#
#
#
#
#
# 2Distribution and habitat
#
#
#
# Toggle Distribution and habitat subsection
#
#
#
#
#
# 2.1Invasive
#
#
#
#
#
# ...

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-enabled vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-zebra-design-disabled" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Python (genus) - Wikipedia
#   </title>
#   <script>
# ...

# %%
soup.p['class']
# Out:
# ['mw-empty-elt']

# %%
soup.find_all('a')
# Out:
# [<a class="mw-jump-link" href="#bodyContent">Jump to content</a>,
#  <a accesskey="z" href="/wiki/Main_Page" title="Visit the main page [z]"><span>Main page</span></a>,
#  <a href="/wiki/Wikipedia:Contents" title="Guides to browsing Wikipedia"><span>Contents</span></a>,
#  <a href="/wiki/Portal:Current_events" title="Articles related to current events"><span>Current events</span></a>,
#  <a accesskey="x" href="/wiki/Special:Random" title="Visit a randomly selected article [x]"><span>Random article</span></a>,
#  <a href="/wiki/Wikipedia:About" title="Learn about Wikipedia and how it works"><span>About Wikipedia</span></a>,
#  <a href="//en.wikipedia.org/wiki/Wikipedia:Contact_us" title="How to contact Wikipedia"><span>Contact us</span></a>,
# ...

# %%
for title in soup.title:
    #print(link.get('href'))
    if "python" in title.text:
        print(title.text)

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-enabled vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-zebra-design-disabled" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Python (genus) - Wikipedia</title>
# ...

# %%
soup.title
# Out:
# <title>Python (genus) - Wikipedia</title>

# %%
soup.find_all('class="mw-redirect"')
# Out:
# []

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-enabled vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-zebra-design-disabled" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Python (genus) - Wikipedia</title>
# ...

# %%
soup.find_all('href="/wiki/"')
# Out:
# []

# %%
species_table = soup.find('table', {'class': 'wikitable'})

# %%
species_tr = species_table.find_all('tr')

# %%
type(species_tr)
# Out:
# bs4.element.ResultSet

# %%
species_tr.count
# Out:
# <function ResultSet.count(value, /)>
